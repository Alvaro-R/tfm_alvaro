# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 5.5
fig_height = 3.5
fig_format = 'pdf'
fig_dpi = 300

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'/Users/alvaroromangomez/Documents/Documentos personales/Formación/Master Bioinformática y Estadística/TFM/tfm_alvaro/Codigo/notebooks':
  os.chdir(r'/Users/alvaroromangomez/Documents/Documentos personales/Formación/Master Bioinformática y Estadística/TFM/tfm_alvaro/Codigo/notebooks')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# {"/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/importlib/_bootstrap.py": 1680292077.4164195, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/importlib/_bootstrap_external.py": 1680292077.4196162, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/codecs.py": 1680292075.8375273, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/encodings/aliases.py": 1680292076.6626852, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/encodings/__init__.py": 1680292076.6596105, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/encodings/utf_8.py": 1680292077.0363183, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/abc.py": 1680292075.7900312, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/io.py": 1680292075.9434319, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/stat.py": 1680292076.0992587, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/_collections_abc.py": 1680292075.7597497, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/genericpath.py": 1680292075.907012, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/posixpath.py": 1680292076.017065, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/os.py": 1680292075.9906452, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/_sitebuiltins.py": 1680292075.7799897, "/Users/alvaroromangomez/.local/share/virtualenvs/tfm_alvaro-vnpVahGc/lib/python3.10/site-packages/_virtualenv.py": 1680293177.5324633, "/Users/alvaroromangomez/.local/share/virtualenvs/tfm_alvaro-vnpVahGc/lib/python3.10/site-packages/_distutils_hack/__init__.py": 1682249829.4227896, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/types.py": 1680292076.1610441, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/warnings.py": 1680292076.171295, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/importlib/__init__.py": 1680292077.4067504, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/importlib/_abc.py": 1680292077.4100232, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/keyword.py": 1680292075.9485064, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/operator.py": 1680292075.985474, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/reprlib.py": 1680292076.0480385, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/collections/__init__.py": 1680292076.2837832, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/functools.py": 1680292075.9044013, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/contextlib.py": 1680292075.851496, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/importlib/util.py": 1680292077.4386227, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/importlib/machinery.py": 1680292077.4289305, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/site.py": 1680292076.0738118, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/runpy.py": 1680292076.0534787, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/enum.py": 1680292075.8887126, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/sre_constants.py": 1680292076.0916119, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/sre_parse.py": 1680292076.0940933, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/sre_compile.py": 1680292076.089039, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/copyreg.py": 1680292075.860719, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/re.py": 1680292076.0454798, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/collections/abc.py": 1680292076.2866344, "/Users/alvaroromangomez/.pyenv/versions/3.10.10/lib/python3.10/typing.py": 1680292076.1636195, "/Users/alvaroromangomez/.local/share/virtualenvs/tfm_alvaro-vnpVahGc/lib/python3.10/site-packages/ip ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pycaret.classification import *

# IMPORT CUSTOM MODULES
import sys

sys.path.append("../src")
import utils.stats as st

# %%
# DIRECTORIES
input_path = "../data/processed/"
train_path = "../data/processed/train_data/"
test_path = "../data/processed/test_data/"
# FILES
# MOLECULAR DESCRIPTORS
molecular_descriptors_training_file = "molecular_descriptors_training.csv"
molecular_descriptors_test_file = "molecular_descriptors_test.csv"
# MACCS KEYS
maccs_keys_training_file = "maccs_keys_training.csv"
maccs_keys_test_file = "maccs_keys_test.csv"
# ECFP4 FINGERPRINTS
ecfp4_fingerprints_training_file = "ecfp4_fingerprints_training.csv"
ecfp4_fingerprints_test_file = "ecfp4_fingerprints_test.csv"

# %%
# LOAD DATA
# MOLECULAR DESCRIPTORS
## TRAINING
molecular_descriptors_training = pd.read_csv(
    train_path + molecular_descriptors_training_file
)
X_training_molecular_descriptors = molecular_descriptors_training.drop(
    columns=["activity"]
)
Y_training_molecular_descriptors = molecular_descriptors_training["activity"]
## TEST
molecular_descriptors_test = pd.read_csv(test_path + molecular_descriptors_test_file)
X_test_molecular_descriptors = molecular_descriptors_test.drop(columns=["activity"])
Y_test_molecular_descriptors = molecular_descriptors_test["activity"]
# MACCS KEYS
## TRAINING
macc_keys_training = pd.read_csv(train_path + maccs_keys_training_file)
X_training_maccs_keys = macc_keys_training.drop(columns=["activity"])
Y_training_maccs_keys = macc_keys_training["activity"]
## TEST
macc_keys_test = pd.read_csv(test_path + maccs_keys_test_file)
X_test_maccs_keys = macc_keys_test.drop(columns=["activity"])
Y_test_maccs_keys = macc_keys_test["activity"]
# ECFP4 FINGERPRINTS
## TRAINING
ecfp4_fingerprints_training = pd.read_csv(train_path + ecfp4_fingerprints_training_file)
X_training_ecfp4_fingerprints = ecfp4_fingerprints_training.drop(columns=["activity"])
Y_training_ecfp4_fingerprints = ecfp4_fingerprints_training["activity"]
## TEST
ecfp4_fingerprints_test = pd.read_csv(test_path + ecfp4_fingerprints_test_file)
X_test_ecfp4_fingerprints = ecfp4_fingerprints_test.drop(columns=["activity"])
Y_test_ecfp4_fingerprints = ecfp4_fingerprints_test["activity"]

# %%
# CREATE MODELS WITH PYCARET
molecular_descriptors_models = setup(
    data=molecular_descriptors_training,
    target="activity",
    test_data=molecular_descriptors_test,
    session_id=123,
)
# Out:
# <style type="text/css">
# #T_5274e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5274e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5274e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5274e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5274e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5274e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5274e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5274e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5274e_row1_col1" class="data row1 col1" >activity</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5274e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5274e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5274e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5274e_row3_col1" class="data row3 col1" >(299, 87)</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5274e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5274e_row4_col1" class="data row4 col1" >(419, 87)</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5274e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5274e_row5_col1" class="data row5 col1" >(299, 87)</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5274e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5274e_row6_col1" class="data row6 col1" >(120, 87)</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5274e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5274e_row7_col1" class="data row7 col1" >86</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5274e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5274e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5274e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5274e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5274e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_5274e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5274e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_5274e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5274e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5274e_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5274e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5274e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5274e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5274e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5274e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5274e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5274e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5274e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5274e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5274e_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5274e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5274e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5274e_row18_col1" class="data row18 col1" >3863</td>
#     </tr>
#   </tbody>
# </table>

# %%
# COMPARE MODELS
best_model = compare_models(verbose=True)
# Out:
# <style type="text/css">
# #T_53a70 th {
#   text-align: left;
# }
# #T_53a70_row0_col0, #T_53a70_row0_col2, #T_53a70_row0_col3, #T_53a70_row1_col0, #T_53a70_row1_col1, #T_53a70_row1_col2, #T_53a70_row1_col4, #T_53a70_row1_col5, #T_53a70_row1_col6, #T_53a70_row1_col7, #T_53a70_row2_col0, #T_53a70_row2_col1, #T_53a70_row2_col2, #T_53a70_row2_col3, #T_53a70_row2_col4, #T_53a70_row2_col5, #T_53a70_row2_col6, #T_53a70_row2_col7, #T_53a70_row3_col0, #T_53a70_row3_col1, #T_53a70_row3_col3, #T_53a70_row3_col4, #T_53a70_row3_col5, #T_53a70_row3_col6, #T_53a70_row3_col7, #T_53a70_row4_col0, #T_53a70_row4_col1, #T_53a70_row4_col2, #T_53a70_row4_col3, #T_53a70_row4_col4, #T_53a70_row4_col5, #T_53a70_row4_col6, #T_53a70_row4_col7, #T_53a70_row5_col0, #T_53a70_row5_col1, #T_53a70_row5_col2, #T_53a70_row5_col3, #T_53a70_row5_col4, #T_53a70_row5_col5, #T_53a70_row5_col6, #T_53a70_row5_col7, #T_53a70_row6_col0, #T_53a70_row6_col1, #T_53a70_row6_col2, #T_53a70_row6_col3, #T_53a70_row6_col4, #T_53a70_row6_col5, #T_53a70_row6_col6, #T_53a70_row6_col7, #T_53a70_row7_col0, #T_53a70_row7_col1, #T_53a70_row7_col2, #T_53a70_row7_col3, #T_53a70_row7_col4, #T_53a70_row7_col5, #T_53a70_row7_col6, #T_53a70_row7_col7, #T_53a70_row8_col0, #T_53a70_row8_col1, #T_53a70_row8_col2, #T_53a70_row8_col3, #T_53a70_row8_col4, #T_53a70_row8_col5, #T_53a70_row8_col6, #T_53a70_row8_col7, #T_53a70_row9_col0, #T_53a70_row9_col1, #T_53a70_row9_col2, #T_53a70_row9_col3, #T_53a70_row9_col4, #T_53a70_row9_col5, #T_53a70_row9_col6, #T_53a70_row9_col7, #T_53a70_row10_col0, #T_53a70_row10_col1, #T_53a70_row10_col2, #T_53a70_row10_col3, #T_53a70_row10_col4, #T_53a70_row10_col5, #T_53a70_row10_col6, #T_53a70_row10_col7, #T_53a70_row11_col0, #T_53a70_row11_col1, #T_53a70_row11_col2, #T_53a70_row11_col3, #T_53a70_row11_col4, #T_53a70_row11_col5, #T_53a70_row11_col6, #T_53a70_row11_col7, #T_53a70_row12_col0, #T_53a70_row12_col1, #T_53a70_row12_col2, #T_53a70_row12_col3, #T_53a70_row12_col4, #T_53a70_row12_col5, #T_53a70_row12_col6, #T_53a70_row12_col7, #T_53a70_row13_col0, #T_53a70_row13_col1, #T_53a70_row13_col2, #T_53a70_row13_col3, #T_53a70_row13_col4, #T_53a70_row13_col5, #T_53a70_row13_col6, #T_53a70_row13_col7, #T_53a70_row14_col0, #T_53a70_row14_col1, #T_53a70_row14_col2, #T_53a70_row14_col3, #T_53a70_row14_col4, #T_53a70_row14_col5, #T_53a70_row14_col6, #T_53a70_row14_col7 {
#   text-align: left;
# }
# #T_53a70_row0_col1, #T_53a70_row0_col4, #T_53a70_row0_col5, #T_53a70_row0_col6, #T_53a70_row0_col7, #T_53a70_row1_col3, #T_53a70_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_53a70_row0_col8, #T_53a70_row1_col8, #T_53a70_row2_col8, #T_53a70_row3_col8, #T_53a70_row4_col8, #T_53a70_row5_col8, #T_53a70_row6_col8, #T_53a70_row7_col8, #T_53a70_row9_col8, #T_53a70_row10_col8, #T_53a70_row11_col8, #T_53a70_row12_col8, #T_53a70_row13_col8, #T_53a70_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_53a70_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_53a70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53a70_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_53a70_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_53a70_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_53a70_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_53a70_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_53a70_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_53a70_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_53a70_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_53a70_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53a70_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_53a70_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_53a70_row0_col1" class="data row0 col1" >0.6518</td>
#       <td id="T_53a70_row0_col2" class="data row0 col2" >0.6510</td>
#       <td id="T_53a70_row0_col3" class="data row0 col3" >0.6305</td>
#       <td id="T_53a70_row0_col4" class="data row0 col4" >0.6707</td>
#       <td id="T_53a70_row0_col5" class="data row0 col5" >0.6419</td>
#       <td id="T_53a70_row0_col6" class="data row0 col6" >0.3038</td>
#       <td id="T_53a70_row0_col7" class="data row0 col7" >0.3118</td>
#       <td id="T_53a70_row0_col8" class="data row0 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_53a70_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_53a70_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_53a70_row1_col1" class="data row1 col1" >0.6386</td>
#       <td id="T_53a70_row1_col2" class="data row1 col2" >0.6769</td>
#       <td id="T_53a70_row1_col3" class="data row1 col3" >0.6519</td>
#       <td id="T_53a70_row1_col4" class="data row1 col4" >0.6401</td>
#       <td id="T_53a70_row1_col5" class="data row1 col5" >0.6398</td>
#       <td id="T_53a70_row1_col6" class="data row1 col6" >0.2783</td>
#       <td id="T_53a70_row1_col7" class="data row1 col7" >0.2839</td>
#       <td id="T_53a70_row1_col8" class="data row1 col8" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_53a70_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_53a70_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_53a70_row2_col1" class="data row2 col1" >0.6323</td>
#       <td id="T_53a70_row2_col2" class="data row2 col2" >0.6988</td>
#       <td id="T_53a70_row2_col3" class="data row2 col3" >0.6248</td>
#       <td id="T_53a70_row2_col4" class="data row2 col4" >0.6371</td>
#       <td id="T_53a70_row2_col5" class="data row2 col5" >0.6226</td>
#       <td id="T_53a70_row2_col6" class="data row2 col6" >0.2647</td>
#       <td id="T_53a70_row2_col7" class="data row2 col7" >0.2719</td>
#       <td id="T_53a70_row2_col8" class="data row2 col8" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_53a70_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_53a70_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_53a70_row3_col1" class="data row3 col1" >0.6322</td>
#       <td id="T_53a70_row3_col2" class="data row3 col2" >0.7008</td>
#       <td id="T_53a70_row3_col3" class="data row3 col3" >0.6043</td>
#       <td id="T_53a70_row3_col4" class="data row3 col4" >0.6383</td>
#       <td id="T_53a70_row3_col5" class="data row3 col5" >0.6102</td>
#       <td id="T_53a70_row3_col6" class="data row3 col6" >0.2643</td>
#       <td id="T_53a70_row3_col7" class="data row3 col7" >0.2711</td>
#       <td id="T_53a70_row3_col8" class="data row3 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_53a70_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_53a70_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_53a70_row4_col1" class="data row4 col1" >0.6321</td>
#       <td id="T_53a70_row4_col2" class="data row4 col2" >0.6875</td>
#       <td id="T_53a70_row4_col3" class="data row4 col3" >0.6314</td>
#       <td id="T_53a70_row4_col4" class="data row4 col4" >0.6321</td>
#       <td id="T_53a70_row4_col5" class="data row4 col5" >0.6290</td>
#       <td id="T_53a70_row4_col6" class="data row4 col6" >0.2646</td>
#       <td id="T_53a70_row4_col7" class="data row4 col7" >0.2670</td>
#       <td id="T_53a70_row4_col8" class="data row4 col8" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_53a70_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_53a70_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_53a70_row5_col1" class="data row5 col1" >0.6220</td>
#       <td id="T_53a70_row5_col2" class="data row5 col2" >0.6915</td>
#       <td id="T_53a70_row5_col3" class="data row5 col3" >0.6110</td>
#       <td id="T_53a70_row5_col4" class="data row5 col4" >0.6225</td>

# %%
# TUNE MODELS
# tuned_molecular_descriptors_models = tune_model(best_model, optimize="AUC", n_iter=100)

# %%
# CREATE MODELS WITH PYCARET
maccs_keys_models = setup(
    data=macc_keys_training,
    target="activity",
    test_data=macc_keys_test,
    session_id=123,
)
# Out:
# <style type="text/css">
# #T_3d971_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3d971">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d971_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3d971_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d971_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d971_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3d971_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d971_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3d971_row1_col1" class="data row1 col1" >activity</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d971_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3d971_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d971_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3d971_row3_col1" class="data row3 col1" >(299, 168)</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d971_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3d971_row4_col1" class="data row4 col1" >(419, 168)</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d971_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3d971_row5_col1" class="data row5 col1" >(299, 168)</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d971_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3d971_row6_col1" class="data row6 col1" >(120, 168)</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d971_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3d971_row7_col1" class="data row7 col1" >167</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d971_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3d971_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d971_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3d971_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3d971_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_3d971_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3d971_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_3d971_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3d971_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_3d971_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3d971_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_3d971_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3d971_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_3d971_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3d971_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_3d971_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3d971_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_3d971_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3d971_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_3d971_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3d971_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3d971_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_3d971_row18_col1" class="data row18 col1" >e3dd</td>
#     </tr>
#   </tbody>
# </table>

# %%
# COMPARE MODELS
compare_models(verbose=True)
# Out:
# <style type="text/css">
# #T_75a63 th {
#   text-align: left;
# }
# #T_75a63_row0_col0, #T_75a63_row0_col2, #T_75a63_row1_col0, #T_75a63_row1_col1, #T_75a63_row1_col2, #T_75a63_row1_col3, #T_75a63_row1_col4, #T_75a63_row1_col5, #T_75a63_row1_col6, #T_75a63_row1_col7, #T_75a63_row2_col0, #T_75a63_row2_col1, #T_75a63_row2_col3, #T_75a63_row2_col4, #T_75a63_row2_col5, #T_75a63_row2_col6, #T_75a63_row2_col7, #T_75a63_row3_col0, #T_75a63_row3_col1, #T_75a63_row3_col2, #T_75a63_row3_col3, #T_75a63_row3_col4, #T_75a63_row3_col5, #T_75a63_row3_col6, #T_75a63_row3_col7, #T_75a63_row4_col0, #T_75a63_row4_col1, #T_75a63_row4_col2, #T_75a63_row4_col3, #T_75a63_row4_col4, #T_75a63_row4_col5, #T_75a63_row4_col6, #T_75a63_row4_col7, #T_75a63_row5_col0, #T_75a63_row5_col1, #T_75a63_row5_col2, #T_75a63_row5_col3, #T_75a63_row5_col4, #T_75a63_row5_col5, #T_75a63_row5_col6, #T_75a63_row5_col7, #T_75a63_row6_col0, #T_75a63_row6_col1, #T_75a63_row6_col2, #T_75a63_row6_col3, #T_75a63_row6_col4, #T_75a63_row6_col5, #T_75a63_row6_col6, #T_75a63_row6_col7, #T_75a63_row7_col0, #T_75a63_row7_col1, #T_75a63_row7_col2, #T_75a63_row7_col3, #T_75a63_row7_col4, #T_75a63_row7_col5, #T_75a63_row7_col6, #T_75a63_row7_col7, #T_75a63_row8_col0, #T_75a63_row8_col1, #T_75a63_row8_col2, #T_75a63_row8_col3, #T_75a63_row8_col4, #T_75a63_row8_col5, #T_75a63_row8_col6, #T_75a63_row8_col7, #T_75a63_row9_col0, #T_75a63_row9_col1, #T_75a63_row9_col2, #T_75a63_row9_col3, #T_75a63_row9_col4, #T_75a63_row9_col5, #T_75a63_row9_col6, #T_75a63_row9_col7, #T_75a63_row10_col0, #T_75a63_row10_col1, #T_75a63_row10_col2, #T_75a63_row10_col3, #T_75a63_row10_col4, #T_75a63_row10_col5, #T_75a63_row10_col6, #T_75a63_row10_col7, #T_75a63_row11_col0, #T_75a63_row11_col1, #T_75a63_row11_col2, #T_75a63_row11_col3, #T_75a63_row11_col4, #T_75a63_row11_col5, #T_75a63_row11_col6, #T_75a63_row11_col7, #T_75a63_row12_col0, #T_75a63_row12_col1, #T_75a63_row12_col2, #T_75a63_row12_col3, #T_75a63_row12_col4, #T_75a63_row12_col5, #T_75a63_row12_col6, #T_75a63_row12_col7, #T_75a63_row13_col0, #T_75a63_row13_col1, #T_75a63_row13_col2, #T_75a63_row13_col3, #T_75a63_row13_col4, #T_75a63_row13_col5, #T_75a63_row13_col6, #T_75a63_row13_col7, #T_75a63_row14_col0, #T_75a63_row14_col1, #T_75a63_row14_col2, #T_75a63_row14_col3, #T_75a63_row14_col4, #T_75a63_row14_col5, #T_75a63_row14_col6, #T_75a63_row14_col7 {
#   text-align: left;
# }
# #T_75a63_row0_col1, #T_75a63_row0_col3, #T_75a63_row0_col4, #T_75a63_row0_col5, #T_75a63_row0_col6, #T_75a63_row0_col7, #T_75a63_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_75a63_row0_col8, #T_75a63_row1_col8, #T_75a63_row2_col8, #T_75a63_row3_col8, #T_75a63_row4_col8, #T_75a63_row5_col8, #T_75a63_row7_col8, #T_75a63_row8_col8, #T_75a63_row9_col8, #T_75a63_row10_col8, #T_75a63_row11_col8, #T_75a63_row12_col8, #T_75a63_row13_col8, #T_75a63_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_75a63_row6_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_75a63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75a63_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75a63_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_75a63_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_75a63_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_75a63_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_75a63_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_75a63_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_75a63_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_75a63_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75a63_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_75a63_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_75a63_row0_col1" class="data row0 col1" >0.6857</td>
#       <td id="T_75a63_row0_col2" class="data row0 col2" >0.7090</td>
#       <td id="T_75a63_row0_col3" class="data row0 col3" >0.7119</td>
#       <td id="T_75a63_row0_col4" class="data row0 col4" >0.6816</td>
#       <td id="T_75a63_row0_col5" class="data row0 col5" >0.6910</td>
#       <td id="T_75a63_row0_col6" class="data row0 col6" >0.3717</td>
#       <td id="T_75a63_row0_col7" class="data row0 col7" >0.3782</td>
#       <td id="T_75a63_row0_col8" class="data row0 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_75a63_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_75a63_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_75a63_row1_col1" class="data row1 col1" >0.6622</td>
#       <td id="T_75a63_row1_col2" class="data row1 col2" >0.6990</td>
#       <td id="T_75a63_row1_col3" class="data row1 col3" >0.6705</td>
#       <td id="T_75a63_row1_col4" class="data row1 col4" >0.6674</td>
#       <td id="T_75a63_row1_col5" class="data row1 col5" >0.6637</td>
#       <td id="T_75a63_row1_col6" class="data row1 col6" >0.3240</td>
#       <td id="T_75a63_row1_col7" class="data row1 col7" >0.3291</td>
#       <td id="T_75a63_row1_col8" class="data row1 col8" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_75a63_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_75a63_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_75a63_row2_col1" class="data row2 col1" >0.6521</td>
#       <td id="T_75a63_row2_col2" class="data row2 col2" >0.7202</td>
#       <td id="T_75a63_row2_col3" class="data row2 col3" >0.6438</td>
#       <td id="T_75a63_row2_col4" class="data row2 col4" >0.6591</td>
#       <td id="T_75a63_row2_col5" class="data row2 col5" >0.6440</td>
#       <td id="T_75a63_row2_col6" class="data row2 col6" >0.3039</td>
#       <td id="T_75a63_row2_col7" class="data row2 col7" >0.3110</td>
#       <td id="T_75a63_row2_col8" class="data row2 col8" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_75a63_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_75a63_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_75a63_row3_col1" class="data row3 col1" >0.6487</td>
#       <td id="T_75a63_row3_col2" class="data row3 col2" >0.6951</td>
#       <td id="T_75a63_row3_col3" class="data row3 col3" >0.6710</td>
#       <td id="T_75a63_row3_col4" class="data row3 col4" >0.6493</td>
#       <td id="T_75a63_row3_col5" class="data row3 col5" >0.6550</td>
#       <td id="T_75a63_row3_col6" class="data row3 col6" >0.2976</td>
#       <td id="T_75a63_row3_col7" class="data row3 col7" >0.3015</td>
#       <td id="T_75a63_row3_col8" class="data row3 col8" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_75a63_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_75a63_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_75a63_row4_col1" class="data row4 col1" >0.6454</td>
#       <td id="T_75a63_row4_col2" class="data row4 col2" >0.6798</td>
#       <td id="T_75a63_row4_col3" class="data row4 col3" >0.6176</td>
#       <td id="T_75a63_row4_col4" class="data row4 col4" >0.6564</td>
#       <td id="T_75a63_row4_col5" class="data row4 col5" >0.6293</td>
#       <td id="T_75a63_row4_col6" class="data row4 col6" >0.2909</td>
#       <td id="T_75a63_row4_col7" class="data row4 col7" >0.2970</td>
#       <td id="T_75a63_row4_col8" class="data row4 col8" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_75a63_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_75a63_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_75a63_row5_col1" class="data row5 col1" >0.6454</td>
#       <td id="T_75a63_row5_col2" class="data row5 col2" >0.6764</td>
#       <td id="T_75a63_row5_col3" class="data row5 col3" >0.6843</td>
#       <td id="T_75a63_row5_col4" class="data row5 col4" >0.6366</td>
#       <t
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)

# %%
# CREATE MODELS WITH PYCARET
ecfp4_fingerprints_models = setup(
    data=ecfp4_fingerprints_training,
    target="activity",
    test_data=ecfp4_fingerprints_test,
    session_id=123,
)
# Out:
# <style type="text/css">
# #T_377aa_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_377aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_377aa_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_377aa_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_377aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_377aa_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_377aa_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_377aa_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_377aa_row1_col1" class="data row1 col1" >activity</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_377aa_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_377aa_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_377aa_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_377aa_row3_col1" class="data row3 col1" >(299, 1025)</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_377aa_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_377aa_row4_col1" class="data row4 col1" >(419, 1025)</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_377aa_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_377aa_row5_col1" class="data row5 col1" >(299, 1025)</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_377aa_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_377aa_row6_col1" class="data row6 col1" >(120, 1025)</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_377aa_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_377aa_row7_col1" class="data row7 col1" >1024</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_377aa_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_377aa_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_377aa_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_377aa_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_377aa_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_377aa_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_377aa_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_377aa_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_377aa_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_377aa_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_377aa_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_377aa_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_377aa_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_377aa_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_377aa_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_377aa_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_377aa_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_377aa_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_377aa_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_377aa_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_377aa_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_377aa_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_377aa_row18_col1" class="data row18 col1" >f45e</td>
#     </tr>
#   </tbody>
# </table>

# %%
# COMPARE MODELS
compare_models(verbose=True)
# Out:
# <style type="text/css">
# #T_ba07b th {
#   text-align: left;
# }
# #T_ba07b_row0_col0, #T_ba07b_row0_col2, #T_ba07b_row0_col3, #T_ba07b_row0_col4, #T_ba07b_row1_col0, #T_ba07b_row1_col1, #T_ba07b_row1_col3, #T_ba07b_row1_col5, #T_ba07b_row1_col6, #T_ba07b_row1_col7, #T_ba07b_row2_col0, #T_ba07b_row2_col1, #T_ba07b_row2_col2, #T_ba07b_row2_col3, #T_ba07b_row2_col4, #T_ba07b_row2_col5, #T_ba07b_row2_col6, #T_ba07b_row2_col7, #T_ba07b_row3_col0, #T_ba07b_row3_col1, #T_ba07b_row3_col2, #T_ba07b_row3_col3, #T_ba07b_row3_col4, #T_ba07b_row3_col5, #T_ba07b_row3_col6, #T_ba07b_row3_col7, #T_ba07b_row4_col0, #T_ba07b_row4_col1, #T_ba07b_row4_col2, #T_ba07b_row4_col3, #T_ba07b_row4_col4, #T_ba07b_row4_col5, #T_ba07b_row4_col6, #T_ba07b_row4_col7, #T_ba07b_row5_col0, #T_ba07b_row5_col1, #T_ba07b_row5_col2, #T_ba07b_row5_col3, #T_ba07b_row5_col4, #T_ba07b_row5_col5, #T_ba07b_row5_col6, #T_ba07b_row5_col7, #T_ba07b_row6_col0, #T_ba07b_row6_col1, #T_ba07b_row6_col2, #T_ba07b_row6_col3, #T_ba07b_row6_col4, #T_ba07b_row6_col5, #T_ba07b_row6_col6, #T_ba07b_row6_col7, #T_ba07b_row7_col0, #T_ba07b_row7_col1, #T_ba07b_row7_col2, #T_ba07b_row7_col3, #T_ba07b_row7_col4, #T_ba07b_row7_col5, #T_ba07b_row7_col6, #T_ba07b_row7_col7, #T_ba07b_row8_col0, #T_ba07b_row8_col1, #T_ba07b_row8_col2, #T_ba07b_row8_col3, #T_ba07b_row8_col4, #T_ba07b_row8_col5, #T_ba07b_row8_col6, #T_ba07b_row8_col7, #T_ba07b_row9_col0, #T_ba07b_row9_col1, #T_ba07b_row9_col2, #T_ba07b_row9_col3, #T_ba07b_row9_col4, #T_ba07b_row9_col5, #T_ba07b_row9_col6, #T_ba07b_row9_col7, #T_ba07b_row10_col0, #T_ba07b_row10_col1, #T_ba07b_row10_col2, #T_ba07b_row10_col4, #T_ba07b_row10_col5, #T_ba07b_row10_col6, #T_ba07b_row10_col7, #T_ba07b_row11_col0, #T_ba07b_row11_col1, #T_ba07b_row11_col2, #T_ba07b_row11_col3, #T_ba07b_row11_col4, #T_ba07b_row11_col5, #T_ba07b_row11_col6, #T_ba07b_row11_col7, #T_ba07b_row12_col0, #T_ba07b_row12_col1, #T_ba07b_row12_col2, #T_ba07b_row12_col3, #T_ba07b_row12_col4, #T_ba07b_row12_col5, #T_ba07b_row12_col6, #T_ba07b_row12_col7, #T_ba07b_row13_col0, #T_ba07b_row13_col1, #T_ba07b_row13_col2, #T_ba07b_row13_col3, #T_ba07b_row13_col4, #T_ba07b_row13_col5, #T_ba07b_row13_col6, #T_ba07b_row13_col7, #T_ba07b_row14_col0, #T_ba07b_row14_col1, #T_ba07b_row14_col2, #T_ba07b_row14_col3, #T_ba07b_row14_col4, #T_ba07b_row14_col5, #T_ba07b_row14_col6, #T_ba07b_row14_col7 {
#   text-align: left;
# }
# #T_ba07b_row0_col1, #T_ba07b_row0_col5, #T_ba07b_row0_col6, #T_ba07b_row0_col7, #T_ba07b_row1_col2, #T_ba07b_row1_col4, #T_ba07b_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ba07b_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ba07b_row1_col8, #T_ba07b_row2_col8, #T_ba07b_row3_col8, #T_ba07b_row4_col8, #T_ba07b_row5_col8, #T_ba07b_row6_col8, #T_ba07b_row7_col8, #T_ba07b_row8_col8, #T_ba07b_row9_col8, #T_ba07b_row10_col8, #T_ba07b_row11_col8, #T_ba07b_row12_col8, #T_ba07b_row13_col8, #T_ba07b_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ba07b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba07b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ba07b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ba07b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ba07b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ba07b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ba07b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ba07b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ba07b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ba07b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba07b_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_ba07b_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_ba07b_row0_col1" class="data row0 col1" >0.7023</td>
#       <td id="T_ba07b_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_ba07b_row0_col3" class="data row0 col3" >0.7048</td>
#       <td id="T_ba07b_row0_col4" class="data row0 col4" >0.7106</td>
#       <td id="T_ba07b_row0_col5" class="data row0 col5" >0.7044</td>
#       <td id="T_ba07b_row0_col6" class="data row0 col6" >0.4047</td>
#       <td id="T_ba07b_row0_col7" class="data row0 col7" >0.4083</td>
#       <td id="T_ba07b_row0_col8" class="data row0 col8" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_ba07b_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_ba07b_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_ba07b_row1_col1" class="data row1 col1" >0.6921</td>
#       <td id="T_ba07b_row1_col2" class="data row1 col2" >0.7363</td>
#       <td id="T_ba07b_row1_col3" class="data row1 col3" >0.6505</td>
#       <td id="T_ba07b_row1_col4" class="data row1 col4" >0.7137</td>
#       <td id="T_ba07b_row1_col5" class="data row1 col5" >0.6761</td>
#       <td id="T_ba07b_row1_col6" class="data row1 col6" >0.3839</td>
#       <td id="T_ba07b_row1_col7" class="data row1 col7" >0.3890</td>
#       <td id="T_ba07b_row1_col8" class="data row1 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_ba07b_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_ba07b_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ba07b_row2_col1" class="data row2 col1" >0.6787</td>
#       <td id="T_ba07b_row2_col2" class="data row2 col2" >0.7341</td>
#       <td id="T_ba07b_row2_col3" class="data row2 col3" >0.6643</td>
#       <td id="T_ba07b_row2_col4" class="data row2 col4" >0.6777</td>
#       <td id="T_ba07b_row2_col5" class="data row2 col5" >0.6669</td>
#       <td id="T_ba07b_row2_col6" class="data row2 col6" >0.3576</td>
#       <td id="T_ba07b_row2_col7" class="data row2 col7" >0.3615</td>
#       <td id="T_ba07b_row2_col8" class="data row2 col8" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_ba07b_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_ba07b_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_ba07b_row3_col1" class="data row3 col1" >0.6655</td>
#       <td id="T_ba07b_row3_col2" class="data row3 col2" >0.7230</td>
#       <td id="T_ba07b_row3_col3" class="data row3 col3" >0.6919</td>
#       <td id="T_ba07b_row3_col4" class="data row3 col4" >0.6746</td>
#       <td id="T_ba07b_row3_col5" class="data row3 col5" >0.6727</td>
#       <td id="T_ba07b_row3_col6" class="data row3 col6" >0.3316</td>
#       <td id="T_ba07b_row3_col7" class="data row3 col7" >0.3416</td>
#       <td id="T_ba07b_row3_col8" class="data row3 col8" >0.1090</td>
#     </tr>
#     <tr>
#       <th id="T_ba07b_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_ba07b_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ba07b_row4_col1" class="data row4 col1" >0.6653</td>
#       <td id="T_ba07b_row4_col2" class="data row4 col2" >0.7298</td>
#       <td id="T_ba07b_row4_col3" class="data row4 col3" >0.6376</td>
#       <td id="T_ba07b_row4_col4" class="data row4 col4" >0.6837</td>
#       <td id="T_ba07b_row4_col5" class="data row4 col5" >0.6561</td>
#       <td id="T_ba07b_row4_col6" class="data row4 col6" >0.3309</td>
#       <td id="T_ba07b_row4_col7" class="data row4 col7" >0.3351</td>
#       <td id="T_ba07b_row4_col8" class="data row4 col8" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_ba07b_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_ba07b_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_ba07b_row5_col1" class="data row5 col1" >0.6585</td>
#       <td id="T_ba07b_row5_col2" class="data row5 col2" >0.7308</td>
#       <td id="T_ba07b_row5_col3" class="data row5 col3" >0.6300</td>
#       <td id="T_ba07b_row5_col4" class="data row5 col4" >0.6767</td>
#       <td id="T_ba07b_row5_col5" c
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=123, solver='auto',
#                 tol=0.0001)
